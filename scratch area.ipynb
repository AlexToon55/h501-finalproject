# %%
# !conda env list

# %%
from modules.survey_extract import load_survey

load_survey() [:10]
# Out:
#             Timestamp   Age          Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                            Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                            Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                            Spotify            4.0
# 3  8/27/2022 21:40:40  61.0                      YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                            Spotify            4.0
# 5  8/27/2022 21:56:50  18.0                            Spotify            5.0
# 6  8/27/2022 22:00:29  18.0                      YouTube Music            3.0
# 7  8/27/2022 22:18:59  21.0                            Spotify            1.0
# 8  8/27/2022 22:33:05  19.0                            Spotify            6.0
# 9  8/27/2022 22:44:03  18.0  I do not use a streaming service.            1.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# ...

# %%
import pandas as pd

df = pd.read_csv("data/mxmh_survey_results.csv")

for col in [

"Age",
"Primary streaming service",
"Hours per day",
"While working",
"Instrumentalist",
"Composer",
"Fav genre",
"Exploratory",
"Foreign languages",
"BPM",
]:
    print(f"{col}: {df[col].nunique()} unique values")
    print(df[col].value_counts().head(3))
    print()
# Out:
# Age: 61 unique values
# Age
# 18.0    85
# 19.0    61
# 17.0    59
# Name: count, dtype: int64
#
# Primary streaming service: 6 unique values
# Primary streaming service
# Spotify                              458
# YouTube Music                         94
# I do not use a streaming service.     71
# Name: count, dtype: int64
#
# Hours per day: 27 unique values
# Hours per day
# 2.0    173
# 3.0    120
# 1.0    117
# Name: count, dtype: int64
#
# While working: 2 unique values
# While working
# Yes    579
# No     154
# Name: count, dtype: int64
#
# Instrumentalist: 2 unique values
# Instrumentalist
# No     497
# Yes    235
# Name: count, dtype: int64
#
# Composer: 2 unique values
# Composer
# No     609
# Yes    126
# Name: count, dtype: int64
#
# Fav genre: 16 unique values
# Fav genre
# Rock     188
# Pop      114
# Metal     88
# Name: count, dtype: int64
#
# Exploratory: 2 unique values
# Exploratory
# Yes    525
# No     211
# Name: count, dtype: int64
#
# ...
